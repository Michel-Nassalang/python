# %%
import numpy as np

# %%
A = np.random.randint(1,10, [4,3])
A
# Out:
# array([[7, 9, 2],
#        [6, 4, 4],
#        [2, 2, 6],
#        [9, 6, 7]])

# %%
A[1,1]
# Out:
# 4

# %%
A[1:3, :2]
# Out:
# array([[6, 4],
#        [2, 2]])

# %%
A[1,:]
# Out:
# array([6, 4, 4])

# %%
B = np.random.randint(0,10, [5,4])
B
# Out:
# array([[2, 0, 3, 8],
#        [9, 0, 3, 7],
#        [0, 9, 5, 1],
#        [8, 1, 4, 5],
#        [6, 7, 2, 7]])

# %%
B[2:4,1:3] = 4
B
# Out:
# array([[2, 0, 3, 8],
#        [9, 0, 3, 7],
#        [0, 4, 4, 1],
#        [8, 4, 4, 5],
#        [6, 7, 2, 7]])

# %%
B[0,2] =7
B
# Out:
# array([[2, 0, 7, 8],
#        [9, 0, 3, 7],
#        [0, 4, 4, 1],
#        [8, 4, 4, 5],
#        [6, 7, 2, 7]])

# %%
 B[B==0] = 3
B
# Out:
# array([[2, 3, 7, 8],
#        [9, 3, 3, 7],
#        [3, 4, 4, 1],
#        [8, 4, 4, 5],
#        [6, 7, 2, 7]])

# %%
B[2:4,2] = 2
B
# Out:
# array([[2, 3, 7, 8],
#        [9, 3, 3, 7],
#        [3, 4, 2, 1],
#        [8, 4, 2, 5],
#        [6, 7, 2, 7]])

# %%
C =np.random.randint(0,9, [8,6])
C
# Out:
# array([[3, 3, 5, 6, 2, 4],
#        [7, 3, 8, 5, 1, 8],
#        [5, 5, 0, 0, 2, 3],
#        [4, 4, 4, 7, 4, 1],
#        [6, 1, 2, 1, 8, 7],
#        [4, 5, 3, 6, 8, 5],
#        [7, 2, 0, 4, 8, 8],
#        [7, 1, 4, 1, 4, 4]])

# %%
C[2,-2:]
# Out:
# array([2, 3])

# %%
C[4:5,-3:-1]
# Out:
# array([[1, 8]])

# %% [markdown]
# # TP

# %%
from scipy import misc

# %%
import matplotlib.pyplot as plt

# %%
face = misc.face()
plt.imshow(face)
plt.show()

# %%
type(face)
# Out:
# numpy.ndarray

# %%
face.shape
# Out:
# (768, 1024, 3)

# %%
face = misc.face(gray=True)
plt.imshow(face, cmap=plt.cm.gray)
plt.show()

# %%
face.shape
# Out:
# (768, 1024)

# %%
face_zoom =face[251:451, 501:800]
plt.imshow(face_zoom, cmap=plt.cm.gray)
face = misc.face(gray=True)
plt.show()

# %%
face = misc.face(gray=True)
face[face<50] =80
lumineux = face
plt.imshow(lumineux, cmap=plt.cm.gray)
plt.show()

# %%
face = misc.face(gray=True)
face[face>225] =80
clair = face
plt.imshow(clair, cmap=plt.cm.gray)
plt.show()
