# %% [markdown]
# # Regression linéaire

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
np.random.seed(0)
x = np.random.randint(15,125, 200)

# %%
np.random.seed(0)
f  = lambda x : x + 2*np.random.randn(x.shape[0])

# %%
y=f(x)

# %%
y.shape
# Out:
# (200,)

# %%
x.shape
# Out:
# (200,)

# %%
y = y.reshape(200,1);
x = x.reshape(200,1);

# %%
plt.figure(figsize=(10,6))
plt.scatter(x,y, c='g')
plt.show()

# %%
x = x.reshape(x.shape[0],1)
y = y.reshape(y.shape[0],1)

# %%
from sklearn.linear_model import LinearRegression

# %%
modele = LinearRegression()
modele.fit(x,y)
modele.score(x,y)
# Out:
# 0.9957960138704749

# %%
L_predictions = modele.predict(x)

# %%
plt.figure(figsize=(7,5))
plt.scatter(x, y, c='b')
plt.plot(x, L_predictions, c='black', lw=4)
plt.show()

# %%
from sklearn.svm import SVR

# %%
model = SVR(C=100)
model.fit(x, y)
model.score(x, y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# 0.9958397271866098

# %%
predictions = model.predict(x)

# %%
plt.figure(figsize=(7,5))
plt.scatter(x, y, c='g')
plt.plot(x, predictions, c='r')
plt.show()

# %%
a = np.array([35]).reshape(a.shape[0], 1)

# %%
a.shape
# Out:
# (1, 1)

# %%
print(model.predict(a))
# Out:
# [36.12481927]

# %%
np.random.seed(0)
#Verifions le resultat de la prediction du modele
print(f(a))
# Out:
# [[38.52810469]]
